# %% [markdown]
# # Data Literacy
# #### University of Tübingen, Winter Term 2020/21
# ## Exercise Sheet 7
# &copy; 2020 Prof. Dr. Philipp Hennig & Marius Hobbhahn
#
# This sheet is **due on Tuesday 22nd of December at 12noon sharp (i.e. before the start of the lecture).**
#
# ---
#
# This weeks exercise is concerned with fitting functions to CO2 trends. You will be working with the CO2.csv dataset you already know from Exercise Sheet 04.
#
# In part I we will look at all recorded data and split it up into the early phase of industrialization, the 19th century and the now+future for part II, III and IV respectively.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
from matplotlib import ticker
from scipy import linalg

# %%
# Make inline plots vector graphics
# %matplotlib inline
from IPython.display import set_matplotlib_formats

set_matplotlib_formats("pdf", "svg")

matplotlib.rc("font", **{"family": "serif", "serif": ["Computer Modern"]})
plt.rcParams["text.usetex"] = True
plt.rcParams["text.latex.preamble"] = r"\usepackage{amsfonts} \usepackage{amsmath}"

# %%
CO2_df = pd.read_csv("CO2.csv")
CO2_df_DE = CO2_df[CO2_df["country"] == "Germany"]
CO2_df_DE.head()

# %% [markdown]
# # Part I: Trend for Germany
#
# Recreate the plot from the lecture. Plot the CO2 emission data for Germany in the entire time span that is available. Add a grid to the background for easier comparison. Add a vertical line at 2050 marking the target date for the Paris Climate Agreements and a horizontal line at 90% of the 1990 level to mark the target value. Add a vertical line at 2030 marking the target date that the EU set itself at 55% of the 1990 CO2 levels. Your axes should be labeled and the plot should have a legend.

# %%
# Make a plot for Germany

# TODO

# %% [markdown]
# # Part II: the early Phases of Industrialisation
#
# Create a plot from 1840 to 1913. Transform the data with the logarithm and perform a linear regression in log space as described in the lecture. Plot the linear regression and the data. Can you read the rate of change (e.g. in how many years the CO2 emissions double) from the result of your linear regression?

# %%
# plot the early industrialisation phase

# TODO

# %%
# linear regression for plot

# TODO

# %%
# How can you read the rate of change from the resulting linear function?

# TODO

# %% [markdown]
# # Part III: the 20th Century
#
# Focus on the timespan from 1900 to 2000. Fit a linear transformation using only the data from 1900 - 1914 and 1960 - 1980. Plot the real data and your linear regression. Do you think there is a model that would describe the data better than a linear function? Write a one sentence answer. You don't have to implement this model.

# %%
# plot for 20th century

# TODO

# %%
# one sentence answer for better model

# TODO

# %% [markdown]
# # Part IV: the Future
#
# Use the trajectory from 1980 to 2018 to train a linear model.
#
# a) Apply the linear model. If we assumed the trend of future years follows the over the last 40 years, when would we reach the Paris Climate Agreement goal of a 90% reduction from the levels of 1990?
#
# b) Create a linear function that starts in 2018 at the last available CO2 data and ends in 2050 at 100 Mt CO$_2$ (we will take this as a concrete target for 2050. As part of the Paris Accords, Germany agreed to be "essentially CO$_2$ neutral by 2050". [In the coalition agreement of 2013, this phrase was associated with a net reduction of "80 to 95%"](https://www.bmu.de/themen/klima-energie/klimaschutz/nationale-klimapolitik/klimaschutzplan-2050/))
#
# c) Repeat the same task as in b) for the [55% reduction in 2030 that the EU recently agreed upon](https://ec.europa.eu/clima/policies/strategies/2030_en).
#
# Once again, visualize your results in one plot.
#
# What does the ratio of slopes between the extrapolated historical trajectory and the needed trajectory for both goals imply in terms of necessary change? Give a brief answer.

# %%
# create the plot

# TODO

# %%
# one-sentence answer to the meaning of the ratio of slopes

# TODO
